# %%
# %matplotlib inline

import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
import pandas as pd
import torchvision
import torchvision.transforms as transforms
from torchvision.utils import make_grid

import matplotlib.pyplot as plt
import numpy as np
from sklearn.model_selection import train_test_split
from music21 import *
from fractions import Fraction
seed =0 
torch.manual_seed(seed)

# %% [markdown]
# # Import data

# %%
class MusicDataset(torch.utils.data.Dataset):

    def __init__(self, right, left, Y, transform = None):
        self.right = right
        self.left = left
        self.Y = Y
        self.transform = transform

    def __len__(self):
        return len(self.Y)

    def __getitem__(self, idx):
        return self.right[idx], self.left[idx], self.Y[idx]
    

def generate_data_loader(right_data, left_data, labels, batch_size):
    
    X = np.arange(right_data.shape[0])
    y = labels
    X_trainval, X_test, y_trainval, y_test = train_test_split(
            X, y, test_size=0.2, stratify=y, random_state=23)
    
    # Split train into train-val
    X_train, X_val, y_train, y_val = train_test_split(
        X_trainval, y_trainval, test_size=0.2, stratify=y_trainval, random_state=42)

    right_train = right_data[X_train]
    right_val = right_data[X_val]
    right_test = right_data[X_test]
    
    left_train = left_data[X_train]
    left_val = left_data[X_val]
    left_test = left_data[X_test]    
    
    train_data = MusicDataset(torch.from_numpy(right_train).float(), 
                              torch.from_numpy(left_train).float(), 
                             torch.from_numpy(y_train).float())
    val_data = MusicDataset(torch.from_numpy(right_val).float(), 
                            torch.from_numpy(left_val).float(),
                           torch.from_numpy(y_val).float())
    test_data = MusicDataset(torch.from_numpy(right_test).float(),
                             torch.from_numpy(left_test).float(),
                            torch.from_numpy(y_test).float())
        
    train_loader = torch.utils.data.DataLoader(
        train_data, batch_size=batch_size, shuffle=False)
    val_loader = torch.utils.data.DataLoader(
        val_data, batch_size=batch_size, shuffle=False)
    test_loader = torch.utils.data.DataLoader(
        test_data, batch_size=batch_size, shuffle=False)
    
    return train_loader, val_loader, test_loader

# %%
right_data = np.load('/Users/fionawu/Documents/2022_Fall/ECE685_Deep_Learning/project/preprocess_data/right_data_small.npy')
left_data = np.load('/Users/fionawu/Documents/2022_Fall/ECE685_Deep_Learning/project/preprocess_data/left_data_small.npy')
labels = np.load('/Users/fionawu/Documents/2022_Fall/ECE685_Deep_Learning/project/preprocess_data/labels_small.npy')
batch_size = 64
train_loader, val_loader, test_loader = generate_data_loader(right_data, left_data, labels, batch_size)

# %%
tdict = {0.25: 0,
 0.5: 1,
 0.75: 2,
 1.0: 3,
 1.25: 4,
 1.5: 5,
 1.75: 6,
 2.0: 7,
 2.25: 8,
 2.5: 9,
 2.75: 10,
 3.0: 11,
 3.25: 12,
 4.0: 13,
 5.0: 14,
 6.0: 15,
 3.5: 16,
 3.75: 17,
 4.25: 18,
 4.5: 19,
 4.75: 20,
 5.25: 21,
 5.5: 22,
 7.0: 23,
 Fraction(1, 6): 24,
 Fraction(5, 12): 25,
 Fraction(2, 3): 26,
 Fraction(5, 3): 27,
 Fraction(23, 12): 28,
 Fraction(8, 3): 29,
 Fraction(11, 3): 30,
 Fraction(1, 3): 31,
 Fraction(1, 12): 32,
 Fraction(5, 6): 33,
 Fraction(4, 3): 34,
 Fraction(7, 3): 35,
 Fraction(10, 3): 36}

# %%
pdict = {24: 0,
 25: 1,
 26: 2,
 27: 3,
 28: 4,
 29: 5,
 30: 6,
 31: 7,
 32: 8,
 33: 9,
 34: 10,
 35: 11,
 36: 12,
 37: 13,
 38: 14,
 39: 15,
 40: 16,
 41: 17,
 42: 18,
 43: 19,
 44: 20,
 45: 21,
 46: 22,
 47: 23,
 48: 24,
 49: 25,
 50: 26,
 51: 27,
 52: 28,
 53: 29,
 54: 30,
 55: 31,
 56: 32,
 57: 33,
 58: 34,
 59: 35,
 60: 36,
 61: 37,
 62: 38,
 63: 39,
 64: 40,
 65: 41,
 66: 42,
 67: 43,
 68: 44,
 69: 45,
 70: 46,
 71: 47,
 72: 48,
 73: 49,
 74: 50,
 75: 51,
 76: 52,
 77: 53,
 78: 54,
 79: 55,
 80: 56,
 81: 57,
 82: 58,
 83: 59,
 84: 60,
 85: 61,
 86: 62,
 87: 63,
 88: 64,
 89: 65,
 90: 66,
 91: 67,
 92: 68,
 93: 69,
 94: 70,
 95: 71,
 96: 72,
 97: 73,
 98: 74,
 99: 75,
 100: 76,
 101: 77}

# %%
vdict = {20: 0,
 21: 1,
 22: 2,
 23: 3,
 24: 4,
 25: 5,
 26: 6,
 27: 7,
 28: 8,
 29: 9,
 30: 10,
 31: 11,
 32: 12,
 33: 13,
 34: 14,
 35: 15,
 36: 16,
 37: 17,
 38: 18,
 39: 19,
 40: 20,
 41: 21,
 42: 22,
 43: 23,
 44: 24,
 45: 25,
 46: 26,
 47: 27,
 48: 28,
 49: 29,
 50: 30,
 51: 31,
 52: 32,
 53: 33,
 54: 34,
 55: 35,
 56: 36,
 57: 37,
 58: 38,
 59: 39,
 60: 40,
 61: 41,
 62: 42,
 63: 43,
 64: 44,
 65: 45,
 66: 46,
 67: 47,
 68: 48,
 69: 49,
 70: 50,
 71: 51,
 72: 52,
 73: 53,
 74: 54,
 75: 55,
 76: 56,
 77: 57,
 78: 58,
 79: 59,
 80: 60,
 81: 61,
 82: 62,
 83: 63,
 84: 64,
 85: 65,
 86: 66,
 87: 67,
 88: 68,
 89: 69,
 90: 70,
 91: 71,
 92: 72,
 93: 73,
 94: 74,
 95: 75}

# %%
id2tdict = {i:t for t,i in tdict.items()}
id2pdict = {i:p for p,i in pdict.items()}
id2vdict = {i:v for v,i in vdict.items()}

# %% [markdown]
# # Model Architecture

# %%
class CVAE(nn.Module):
    def __init__(self,p_in,d_in,v_in,p_h,d_h,v_h,n_hid_1,n_hid_2,n_hid_3,n_hid_4,z_dim):  
        super(CVAE, self).__init__()
        
        ##################################### encode layer #####################################
        ### parallel LSTM 
        self.classes = 3 
        self.num_nodes = 50
        
        # LSTM for pitch  
        self.en_p = nn.LSTM(input_size = p_in+self.classes,
                                hidden_size = p_h,
                                num_layers= 1,
                                batch_first=True,
                                bidirectional = False) 
        
        self.en_bn_p = nn.BatchNorm1d(self.num_nodes, affine=False)
        
        # LSTM for duration 
        self.en_d = nn.LSTM(input_size = d_in+self.classes,
                                hidden_size = d_h,
                                num_layers= 1,
                                batch_first=True,
                                bidirectional = False) 
         
        self.en_bn_d = nn.BatchNorm1d(self.num_nodes, affine=False)
        
        # LSTM for velocity 
        
        self.en_v = nn.LSTM(input_size = v_in+self.classes,
                                hidden_size = v_h,
                                num_layers= 1,
                                batch_first=True,
                                bidirectional = False) 
         
        self.en_bn_v = nn.BatchNorm1d(self.num_nodes, affine=False)
        
        
        ### dense
        
        self.en_d1  = nn.Linear(5000,n_hid_2)  # 5000 = 50*100 , n_hid_2= 2500
        self.dropout = nn.Dropout(p=0.5)
        
        self.en_d2  = nn.Linear(n_hid_2,n_hid_3) # n_hid_3 =1000
        
        self.en_d3  = nn.Linear(n_hid_3,n_hid_4) # n_hid_4 = 500
        
        self.en_mu = nn.Linear(n_hid_4,z_dim)  # z_dim= 50
        self.en_var = nn.Linear(n_hid_4,z_dim)  
        
        ##################################### decode layer #####################################
        ### dense 
        self.de_d1= nn.Linear(z_dim+self.classes,n_hid_4)
        self.de_bn_d1 = nn.BatchNorm1d(n_hid_4, affine=False)
        
        self.de_d2_p= nn.Linear(n_hid_4,n_hid_3)
        self.de_bn_d2p = nn.BatchNorm1d(n_hid_3, affine=False)
        self.de_d2_d= nn.Linear(n_hid_4,n_hid_3)
        self.de_bn_d2d = nn.BatchNorm1d(n_hid_3, affine=False)
        self.de_d2_v= nn.Linear(n_hid_4,n_hid_3)
        self.de_bn_d2v = nn.BatchNorm1d(n_hid_3, affine=False)
        
        self.de_d3_p= nn.Linear(n_hid_3,n_hid_2)
        self.de_bn_d3p = nn.BatchNorm1d(n_hid_2, affine=False)
        self.de_d3_d= nn.Linear(n_hid_3,n_hid_2)
        self.de_bn_d3d = nn.BatchNorm1d(n_hid_2, affine=False)
        self.de_d3_v= nn.Linear(n_hid_3,n_hid_2)
        self.de_bn_d3v = nn.BatchNorm1d(n_hid_2, affine=False)
        
        ### parallel LSTM 
        self.de_p = nn.LSTM(input_size = n_hid_1,
                             hidden_size= p_in,
                             num_layers=1,
                             batch_first=True,
                             bidirectional = False)
        
        self.de_bn_p = nn.BatchNorm1d(self.num_nodes, affine=False)
        
        
        self.de_d = nn.LSTM(input_size = n_hid_1,
                             hidden_size= d_in,
                             num_layers=1,
                             batch_first=True,
                             bidirectional = False)
        
        self.de_bn_d = nn.BatchNorm1d(self.num_nodes, affine=False)
        
        
        self.de_v = nn.LSTM(input_size = n_hid_1,
                             hidden_size= v_in,
                             num_layers=1,
                             batch_first=True,
                             bidirectional = False)
        
        self.de_bn_v = nn.BatchNorm1d(self.num_nodes, affine=False)
        
        
        
    def parallel_lstm(self,xp,xd,xv,label):
        
        ### concat x with label 
        xp_c = torch.cat((xp,label),dim=2)
        xd_c = torch.cat((xd,label),dim=2)
        xv_c = torch.cat((xv,label),dim=2)
        
        
        output_p,_ = self.en_p(xp_c)
        output_p = F.relu(self.en_bn_p(output_p))

        output_d,_ = self.en_d(xd_c)
        output_d = F.relu(self.en_bn_d(output_d))
        
        output_v,_ = self.en_v(xv_c)
        output_v = F.relu(self.en_bn_v(output_v))
        
        return output_p,output_d,output_v 
        
    def dense(self,xp,xd,xv,label):
        
        output_p,output_d,output_v = self.parallel_lstm(xp,xd,xv,label)
        output = torch.cat((output_p,output_d,output_v),dim=-1)  # batch_size*50*100 
        output = output.view(output.size(0),-1)  # convert to batch_size* 5000
        output = self.dropout(output)
        
        dense_1 = self.en_d1(output)
        dense_1 = F.relu(self.dropout(dense_1))
        
        dense_2 = self.en_d2(dense_1)
        dense_2 = F.relu(self.dropout(dense_2))
        
        dense_3 = self.en_d3(dense_2)
        dense_3 = F.relu(dense_3)
       
        return dense_3
    
    def encode(self,xp,xd,xv,label):
        dense=self.dense(xp,xd,xv,label)
        mu = self.en_mu(dense)
        logvar = self.en_var(dense) 
        return mu,logvar
    
    def reparameterize(self, mu, logvar):
        
        stdev = torch.exp(0.5*logvar)
        eps = torch.randn_like(stdev)
        z= mu + eps*stdev
        return z 
    
    def decode(self, z, label):
        
        ### concate z with label 
        z= torch.cat((z,label),dim=-1) # z_dim =53
        out = self.de_d1(z) 
        out = F.relu(self.de_bn_d1(out))
        
        out_p1 = self.de_d2_p(out)
        out_p1 = F.relu(self.de_bn_d2p(out_p1))
        out_d1 = self.de_d2_d(out)
        out_d1 = F.relu(self.de_bn_d2d(out_d1))
        out_v1 = self.de_d2_v(out)
        out_v1 = F.relu(self.de_bn_d2v(out_v1))
        
        
        out_p2 = self.de_d3_p(out_p1)
        out_p2 = F.relu(self.de_bn_d3p(out_p2))
        out_d2 = self.de_d3_d(out_d1)
        out_d2 = F.relu(self.de_bn_d3d(out_d2))
        out_v2 = self.de_d3_v(out_v1)
        out_v2 = F.relu(self.de_bn_d3v(out_v2))
    

        
        out_p=out_p2.view(out_p2.size(0),50,50)
        out_d=out_d2.view(out_d2.size(0),50,50)
        out_v=out_v2.view(out_v2.size(0),50,50)
        
        
        decode_p,_=self.de_p(out_p)
        decode_p = self.de_bn_p(decode_p)
        decode_d,_=self.de_d(out_d)
        decode_d = self.de_bn_d(decode_d)
        decode_v,_=self.de_v(out_v)
        decode_v = self.de_bn_v(decode_v)
        
        new_p = torch.softmax(decode_p,dim=2)   # softmax for pitch 
        new_d = torch.softmax(decode_d,dim=2) # softmax for pitch duration 
        new_v = torch.softmax(decode_v,dim=2) # softmax for velocity 
        output = torch.cat((new_p, new_d, new_v), dim=2)
    
        return output
    
    def forward(self,data,label_3d,label):
        pitch = data[:,:,:p_in]
        duration = data[:,:,p_in:p_in+d_in]
        velocity = data[:,:,p_in+d_in:]
        
        mu,logvar = self.encode(pitch,duration,velocity,label_3d)
        z = self.reparameterize(mu,logvar)
        output = self.decode(z,label)
        
        return output,mu,logvar

# %%
def loss_function(recon_data, data, mu, logvar):
    CE = F.cross_entropy(recon_data, data) # BCE = -Negative Log-likelihood
    KLD = -0.5 * torch.sum(1 + logvar - mu.pow(2) - logvar.exp()) # KL Divergence b/w q_\phi(z|x) || p(z)
    return CE + KLD

# %%
def train(model,optimizer,train_loader):
    train_loss = 0
    BCE_right_loss = 0 
    BCE_left_loss = 0
    KLD_loss = 0 
    model.train()
    criterion  = nn.MSELoss()
    for idx, (right_data,left_data,label) in enumerate(train_loader):
        ## preprocess label 
        data = right_data  ## only choose right data to be data 
        label_3d=torch.unsqueeze(label,1)
        label_3d=label_3d.repeat_interleave(50,dim=1) 
        ### 
        optimizer.zero_grad()
        output,mu,logvar = model(data,label_3d,label)
       
        loss = loss_function(output,data, mu,logvar)
        loss.backward()
        optimizer.step()
        train_loss += loss.item()
        
    return  train_loss/len(train_loader)

def val(model,val_loader):
    model.eval()
    val_loss = 0
    with torch.no_grad():
        for idx, (right_data,left_data,label) in enumerate(val_loader):
            data = right_data
            label_3d=torch.unsqueeze(label,1)
            label_3d=label_3d.repeat_interleave(50,dim=1) 
            
            output,mu,logvar = model(data,label_3d,label)
            
            loss = loss_function(output,data, mu,logvar)
            val_loss += loss.item() # sum up batch loss
   
        return val_loss/len(val_loader)

def plot_loss(train_loss,val_loss):
    
    X=range(1,len(train_loss)+1)
    plt.plot(X,train_loss,"-b",label="Train")
    plt.plot(X,val_loss,"-r",label="Val")
    plt.legend()
    plt.xlabel('epoch')
    plt.ylabel('loss')
    plt.show()

# %%
p_in = 78
d_in = 37
v_in = 76
p_h = 39
d_h = 23
v_h = 38
n_hid_1= 50
n_hid_2= 2500
n_hid_3 =1000
n_hid_4 = 500
z_dim= 50
num_epochs = 100
lr = 0.0001
decay = 0.0001

# %%
train_loss_all=[]
val_loss_all = [] 
torch.autograd.set_detect_anomaly(True)

model=CVAE(p_in,d_in,v_in,p_h,d_h,v_h,n_hid_1,n_hid_2,n_hid_3,n_hid_4,z_dim)
optimizer= optim.Adam(model.parameters(),lr= lr, weight_decay= decay)
for epoch in range(1, num_epochs + 1):
    train_loss = train(model,optimizer,train_loader)
    train_loss_all.append(train_loss)
    print("for epoch {}, train loss is {}".format(epoch,train_loss))
    val_loss = val(model,val_loader)
    val_loss_all.append(val_loss)
    print("for epoch {}, validation loss is {}".format(epoch,val_loss))
plot_loss(train_loss_all,val_loss_all)
# Out:
# for epoch 1, train loss is 5.591619295733316
# for epoch 1, validation loss is 4.347300938197544
# for epoch 2, train loss is 3.721015623637608
# for epoch 2, validation loss is 3.978565522602626
# for epoch 3, train loss is 3.593874360833849
# for epoch 3, validation loss is 3.829380512237549
# for epoch 4, train loss is 3.544987048421587
# for epoch 4, validation loss is 3.7816477503095354
# for epoch 5, train loss is 3.516476333141327
# for epoch 5, validation loss is 3.6911048207964217
# for epoch 6, train loss is 3.4962615030152455
# for epoch 6, validation loss is 3.621857064110892
# for epoch 7, train loss is 3.4813949976648604
# for epoch 7, validation loss is 3.5569839818137035
# for epoch 8, train loss is 3.4686264055115834
# for epoch 8, validation loss is 3.494122096470424
# for epoch 9, train loss is 3.45727892432894
# for epoch 9, validation loss is 3.450866903577532
# for epoch 10, train loss is 3.447604179382324
# for epoch 10, validation loss is 3.430572714124407
# for epoch 11, train loss is 3.440780426774706
# for epoch 11, validation loss is 3.4267723900931224
# for epoch 12, train loss is 3.437142942632948
# for epoch 12, validation loss is 3.426469223839896
# for epoch 13, train loss is 3.4356941836220876
# for epoch 13, validation loss is 3.4261984484536305
# for epoch 14, train loss is 3.4341607178960527
# for epoch 14, validation loss is 3.4259964738573347
# for epoch 15, train loss is 3.43319605078016
# for epoch 15, validation loss is 3.426010710852487
# for epoch 16, train loss is 3.432429322174617
# for epoch 16, validation loss is 3.425999811717442
# for epoch 17, train loss is 3.4319760458809987
# for epoch 17, validation loss is 3.4259917395455495
# for epoch 18, train loss is 3.431529871055058
# for epoch 18, validation loss is 3.426055874143328
# for epoch 19, train loss is 3.4310438547815596
# for epoch 19, validation loss is 3.4260100977761403
# for epoch 20, train loss is 3.4307290485927036
# for epoch 20, validation loss is 3.425924709865025
# for epoch 21, train loss is 3.4302196162087575
# for epoch 21, validation loss is 3.4259752886635915
# for epoch 22, train loss is 3.429920188018254
# for epoch 22, validation loss is 3.4259177957262312
# for epoch 23, train loss is 3.4296259028570995
# for epoch 23, validation loss is 3.4258417061397006
# for epoch 24, train loss is 3.4293135149138316
# for epoch 24, validation loss is 3.4258908884865895
# for epoch 25, train loss is 3.4289813552583968
# for epoch 25, validation loss is 3.426013571875436
# for epoch 26, train loss is 3.4288397261074612
# for epoch 26, validation loss is 3.425914560045515
# for epoch 27, train loss is 3.428543584687369
# for epoch 27, validation loss is 3.4260502883366177
# for epoch 28, train loss is 3.4282918657575334
# for epoch 28, validation loss is 3.4259095873151506
# for epoch 29, train loss is 3.4283150093896047
# for epoch 29, validation loss is 3.4260092803410123
# for epoch 30, train loss is 3.4278766683169772
# for epoch 30, validation loss is 3.425919941493443
# for epoch 31, train loss is 3.427800919328417
# for epoch 31, validation loss is 3.426142386027745
# for epoch 32, train loss is 3.427632544721876
# for epoch 32, validation loss is 3.426197052001953
# for epoch 33, train loss is 3.4273837889943803
# for epoch 33, validation loss is 3.4260308061327254
# for epoch 34, train loss is 3.427156218460628
# for epoch 34, validation loss is 3.426105805805751
# for epoch 35, train loss is 3.4269101534570967
# for epoch 35, validation loss is 3.426131180354527
# for epoch 36, train loss is 3.4268429705074857
# for epoch 36, validation loss is 3.4262382302965437
# for epoch 37, train loss is 3.4265457136290416
# for epoch 37, validation loss is 3.4263318947383334
# for epoch 38, train loss is 3.426502730165209
# for epoch 38, validation loss is 3.426117624555315
# for epoch 39, train loss is 3.4263595087187633
# for epoch 39, validation loss is 3.4262500490461076
# for epoch 40, train loss is 3.426142062459673
# for epoch 40, validation loss is 3.426389047077724
# for epoch 41, train loss is 3.4260204264095853
# for epoch 41, validation loss is 3.4264323711395264
# for epoch 42, train loss is 3.4259176339421953
# for epoch 42, validation loss is 3.426602397646223
# for epoch 43, train loss is 3.4257141011101857
# for epoch 43, validation loss is 3.4265194620404924
# for epoch 44, train loss is 3.4256367683410645
# for epoch 44, validation loss is 3.42648492540632
# for epoch 45, train loss is 3.42547801562718
# for epoch 45, validation loss is 3.426517827170236
# for epoch 46, train loss is 3.4255029473985945
# for epoch 46, validation loss is 3.4267519542149136
# for epoch 47, train loss is 3.4252527185848782
# for epoch 47, validation loss is 3.4265179293496266
# for epoch 48, train loss is 3.4252765689577376
# for epoch 48, validation loss is 3.426588467189244
# for epoch 49, train loss is 3.4250947662762234
# for epoch 49, validation loss is 3.426560401916504
# for epoch 50, train loss is 3.425035664013454
# for epoch 50, validation loss is 3.4265807356153215
# for epoch 51, train loss is 3.4249288695199147
# for epoch 51, validation loss is 3.4267054285321916
# for epoch 52, train loss is 3.424907616206578
# for epoch 52, validation loss is 3.4266154766082764
# for epoch 53, train loss is 3.4248210958072116
# for epoch 53, validation loss is 3.4266297817230225
# for epoch 54, train loss is 3.4247287256377086
# for epoch 54, validation loss is 3.4267591408320834
# for epoch 55, train loss is 3.4246209263801575
# for epoch 55, validation loss is 3.4268947328839983
# for epoch 56, train loss is 3.4244629655565535
# for epoch 56, validation loss is 3.426880053111485
# for epoch 57, train loss is 3.424492393221174
# for epoch 57, validation loss is 3.4267282485961914
# for epoch 58, train loss is 3.4244878121784756
# for epoch 58, validation loss is 3.426820993423462
# for epoch 59, train loss is 3.424445595060076
# for epoch 59, validation loss is 3.4268668719700406
# for epoch 60, train loss is 3.424353914601462
# for epoch 60, validation loss is 3.4268613883427212
# for epoch 61, train loss is 3.4242357356207713
# for epoch 61, validation loss is 3.426811729158674
# for epoch 62, train loss is 3.4243320567267284
# for epoch 62, validation loss is 3.4267735140664235
# for epoch 63, train loss is 3.424142667225429
# for epoch 63, validation loss is 3.426657097680228
# for epoch 64, train loss is 3.4242410148893083
# for epoch 64, validation loss is 3.4269638061523438
# for epoch 65, train loss is 3.4240897383008684
# for epoch 65, validation loss is 3.4268510001046315
# for epoch 66, train loss is 3.4241901295525685
# for epoch 66, validation loss is 3.4269703115735735
# for epoch 67, train loss is 3.4240672418049405
# for epoch 67, validation loss is 3.426741531917027
# for epoch 68, train loss is 3.424134228910719
# for epoch 68, validation loss is 3.4269093445369174
# for epoch 69, train loss is 3.4240204180989946
# for epoch 69, validation loss is 3.4268183367592946
# for epoch 70, train loss is 3.4239023412976946
# for epoch 70, validation loss is 3.426960366112845
# for epoch 71, train loss is 3.4239323820386613
# for epoch 71, validation loss is 3.4268105030059814
# for epoch 72, train loss is 3.4239520856312344
# for epoch 72, validation loss is 3.4269974572317943
# for epoch 73, train loss is 3.4238765835762024
# for epoch 73, validation loss is 3.4268219811575755
# for epoch 74, train loss is 3.4239161099706377
# for epoch 74, validation loss is 3.4269253526415144
# for epoch 75, train loss is 3.423900408404214
# for epoch 75, validation loss is 3.4268177918025424
# for epoch 76, train loss is 3.423875723566328
# for epoch 76, validation loss is 3.426745823451451
# for epoch 77, train loss is 3.4238749657358443
# for epoch 77, validation loss is 3.4268385001591275
# for epoch 78, train loss is 3.4237935713359287
# for epoch 78, validation loss is 3.4269558361598422
# for epoch 79, train loss is 3.4237683500562395
# for epoch 79, validation loss is 3.426759890147618
# for epoch 80, train loss is 3.4237888199942454
# for epoch 80, validation loss is 3.4268694264548167
# for epoch 81, train loss is 3.423724123409816
# for epoch 81, validation loss is 3.426987886428833
# for epoch 82, train loss is 3.423645487853459
# for epoch 82, validation loss is 3.4268954481397356
# for epoch 83, train loss is 3.423605578286307
# for epoch 83, validation loss is 3.4269136360713413
# for epoch 84, train loss is 3.4236460498401096
# for epoch 84, validation loss is 3.4269534860338484
# for epoch 85, train loss is 3.423681386879512
# for epoch 85, validation loss is 3.426697015762329
# for epoch 86, train loss is 3.4237117597035
# for epoch 86, validation loss is 3.426855972834996
# for epoch 87, train loss is 3.4234535098075867
# for epoch 87, validation loss is 3.4270389761243547
# for epoch 88, train loss is 3.4235311576298306
# for epoch 88, validation loss is 3.4269099916730608
# for epoch 89, train loss is 3.423392014844077
# for epoch 89, validation loss is 3.426793098449707
# for epoch 90, train loss is 3.4234564815248762
# for epoch 90, validation loss is 3.4268538611275807
# for epoch 91, train loss is 3.4234752569879805
# for epoch 91, validation loss is 3.427060910633632
# for epoch 92, train loss is 3.4234820944922313
# for epoch 92, validation loss is 3.426970992769514
# for epoch 93, train loss is 3.42344263621739
# for epoch 93, validation loss is 3.427053451538086
# for epoch 94, train loss is 3.423587603228433
# for epoch 94, validation loss is 3.426873343331473
# for epoch 95, train loss is 3.423455204282488
# for epoch 95, validation loss is 3.4269134998321533
# for epoch 96, train loss is 3.423363838876997
# for epoch 96, validation loss is 3.426936626434326
# for epoch 97, train loss is 3.4234053237097606
# for epoch 97, validation loss is 3.426879848752703
# for epoch 98, train loss is 3.4234612669263567
# for epoch 98, validation loss is 3.427001714706421
# for epoch 99, train loss is 3.42346738917487
# for epoch 99, validation loss is 3.4269676889692033
# for epoch 100, train loss is 3.4233804515429904
# for epoch 100, validation loss is 3.4268923486982072

# %%
model
# Out:
# CVAE(
#   (en_p): LSTM(81, 39, batch_first=True)
#   (en_bn_p): BatchNorm1d(50, eps=1e-05, momentum=0.1, affine=False, track_running_stats=True)
#   (en_d): LSTM(40, 23, batch_first=True)
#   (en_bn_d): BatchNorm1d(50, eps=1e-05, momentum=0.1, affine=False, track_running_stats=True)
#   (en_v): LSTM(79, 38, batch_first=True)
#   (en_bn_v): BatchNorm1d(50, eps=1e-05, momentum=0.1, affine=False, track_running_stats=True)
#   (en_d1): Linear(in_features=5000, out_features=2500, bias=True)
#   (dropout): Dropout(p=0.5, inplace=False)
#   (en_d2): Linear(in_features=2500, out_features=1000, bias=True)
#   (en_d3): Linear(in_features=1000, out_features=500, bias=True)
#   (en_mu): Linear(in_features=500, out_features=50, bias=True)
#   (en_var): Linear(in_features=500, out_features=50, bias=True)
#   (de_d1): Linear(in_features=53, out_features=500, bias=True)
#   (de_bn_d1): BatchNorm1d(500, eps=1e-05, momentum=0.1, affine=False, track_running_stats=True)
#   (de_d2_p): Linear(in_features=500, out_features=1000, bias=True)
#   (de_bn_d2p): BatchNorm1d(1000, eps=1e-05, momentum=0.1, affine=False, track_running_stats=True)
#   (de_d2_d): Linear(in_features=500, out_features=1000, bias=True)
#   (de_bn_d2d): BatchNorm1d(1000, eps=1e-05, momentum=0.1, affine=False, track_running_stats=True)
#   (de_d2_v): Linear(in_features=500, out_features=1000, bias=True)
#   (de_bn_d2v): BatchNorm1d(1000, eps=1e-05, momentum=0.1, affine=False, track_running_stats=True)
#   (de_d3_p): Linear(in_features=1000, out_features=2500, bias=True)
#   (de_bn_d3p): BatchNorm1d(2500, eps=1e-05, momentum=0.1, affine=False, track_running_stats=True)
#   (de_d3_d): Linear(in_features=1000, out_features=2500, bias=True)
#   (de_bn_d3d): BatchNorm1d(2500, eps=1e-05, momentum=0.1, affine=False, track_running_stats=True)
#   (de_d3_v): Linear(in_features=1000, out_features=2500, bias=True)
#   (de_bn_d3v): BatchNorm1d(2500, eps=1e-05, momentum=0.1, affine=False, track_running_stats=True)
#   (de_p): LSTM(50, 78, batch_first=True)
#   (de_bn_p): BatchNorm1d(50, eps=1e-05, momentum=0.1, affine=False, track_running_stats=True)
#   (de_d): LSTM(50, 37, batch_first=True)
#   (de_bn_d): BatchNorm1d(50, eps=1e-05, momentum=0.1, affine=False, track_running_stats=True)
#   (de_v): LSTM(50, 76, batch_first=True)
#   (de_bn_v): BatchNorm1d(50, eps=1e-05, momentum=0.1, affine=False, track_running_stats=True)
# )

# %% [markdown]
# # Reconstruct evaluation

# %%
def convert2notes(pid, tid, vid, offset,right=True):

    result = note.Note(id2pdict[pid])
    result.offset = offset
    result.storedInstrument = instrument.Piano()
    result.duration.quarterLength = id2tdict[tid]
    # print(id2tdict[tid])
    result.volume.velocity = id2vdict[vid]

    return result

def construct_music(output,name):
    
    output = output.squeeze()
    output_p = output[:,:len(pdict)]
    output_t = output[:,len(pdict):len(pdict)+len(tdict)]
    output_v = output[:,len(pdict)+len(tdict):]


    p = torch.argmax(output_p, dim=1).detach()
    t = torch.argmax(output_t, dim=1).detach()
    v = torch.argmax(output_v, dim=1).detach()
    
    notes = []
    offset = 0
    for pid, tid, vid in zip(p,t,v):

        n = convert2notes(pid.item(), tid.item(), vid.item(), offset)
        offset += n.duration.quarterLength
        notes.append(n)

    midi_stream = stream.Stream(notes)
    midi_stream.write('midi', fp= name)

# %%
#### reconstruct 
right_data, left_data, label= next(iter(train_loader))
right_data = right_data[1:2]
data = right_data
left_data = left_data[1:2]
label = label[1:2]
label_3d=torch.unsqueeze(label,1)
label_3d=label_3d.repeat_interleave(50,dim=1) 
model.eval()
output, mu,logvar = model(data,label_3d,label)

construct_music(output,'test.mid')

# %%
t
# Out:
# tensor([ 2,  0,  2,  5,  2,  7,  7,  2,  2,  2,  1,  7, 26,  5,  5,  5, 11, 11,
#         11,  7,  5,  2,  7,  7,  7,  2,  1,  2,  1, 11, 26, 11,  1,  1, 26,  1,
#          1,  1,  2,  1,  1,  5, 11,  2, 11, 11,  7, 26, 26,  3])

# %% [markdown]
# # Music Generation with Probability

# %%
z = torch.randn([1, z_dim])
prob = torch.tensor([0.6, 0.2, 0.2])
label=torch.unsqueeze(prob,0)
#label=label.repeat_interleave(50,dim=0)
model.eval()
output = model.decode(z,label)
construct_music(output,'music_cvae_3rolls.mid')
